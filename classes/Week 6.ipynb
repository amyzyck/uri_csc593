# %% [markdown]
# # CSC 593
#
# ## Week 6
#
# ### Introduction to Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Reading files

# %% [markdown]
# ##### Basics
#
# **CSV**
#
# [`pd.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
#load a csv.
nhis_person = pd.read_csv('../data/nhis/personsx.csv')
nhis_person.head()
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1    1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2    2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
#
#    ASTATFLG  ...  EDUC1  ERNYR_P  ARMFTM7P  ARMFTM1P  ARMFTM2P  ARMFTM3P  \
# 0       1.0  ...      9      NaN       NaN       NaN       NaN       NaN
# 1       2.0  ...     14      NaN       NaN       NaN       NaN       NaN
# 2       0.0  ...     15      7.0       NaN       NaN       NaN       NaN
# 3       NaN  ...     10      NaN       NaN       NaN       NaN       NaN
# 4       1.0  ...     21     11.0       NaN       NaN       NaN       NaN
#
#    ARMFTM4P  ARMFTM5P  ARMFTM6P  ENGLANG
# 0       NaN       NaN       NaN      1.0
# 1       NaN       NaN       NaN      1.0
# 2       NaN       NaN       NaN      1.0
# 3       NaN       NaN       NaN      1.0
# 4       NaN       NaN       NaN      1.0
#
# [5 rows x 602 columns]

# %% [markdown]
# **Excel**

# %% [markdown]
# [`pd.read_excel()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html)

# %%
#sheet_name is optional if you want the first (or only) sheet.
bookreq = pd.read_excel('../data/book_requests.xlsx', sheet_name=0)
bookreq.head()
# Out:
#   semester  year  total_book_requests  rock_book_requests  \
# 0     Fall  2005                 1207                 786
# 1   Spring  2006                 1490                 941
# 2   Summer  2006                   38                   2
# 3     Fall  2006                 1190                 915
# 4   Spring  2007                 1410                1086
#
#    scili_book_requests  orwig_book_requests  hay_book_requests
# 0                  115                  306                  0
# 1                  133                  416                  0
# 2                    5                   31                  0
# 3                  153                  122                  0
# 4                  114                  206                  4

# %% [markdown]
# The simple options only work for files that are formatted in a specific way: Headers on the first row, with data immediately under them. Pandas will try to guess the correct type for each column (integer, floating-point number, string, etc.)

# %% [markdown]
# **Fixed Width**

# %% [markdown]
# [`read_fwf()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_fwf.html)

# %%
icd = pd.read_fwf('../data/icd10cm_codes_2020.txt')
icd.head()
# Out:
#     A000 Cholera due to Vibrio cholerae 01, biovar cholerae
# 0   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 1   A009                               Cholera, unspecified
# 2  A0100                         Typhoid fever, unspecified
# 3  A0101                                 Typhoid meningitis
# 4  A0102               Typhoid fever with heart involvement

# %%
#Specify column names
icd = pd.read_fwf('../data/icd10cm_codes_2020.txt', 
                  names=['code', 'description'])
icd.head()
# Out:
#     code                                        description
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis

# %%
#Specify column locations.
icd = pd.read_fwf('../data/icd10cm_codes_2020.txt', 
                  colspecs=((0,7),(8,72)), 
                  names=['code', 'description'])
icd.head()
# Out:
#     code                                        description
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis

# %%
banner = pd.read_excel('../data/courselist.xlsx', sheet_name=0, nrows=1)

colnames = list(banner.columns)
print(colnames)
banner2 = pd.read_excel('../data/courselist.xlsx', sheet_name=0,
                    names=colnames, skiprows=range(10), nrows=10)
banner2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-02dc20291aea> in <module>
# ----> 1 banner = pd.read_excel('../data/courselist.xlsx', sheet_name=0, nrows=1)
#       2
#       3 colnames = list(banner.columns)
#       4 print(colnames)
#       5 banner2 = pd.read_excel('../data/courselist.xlsx', sheet_name=0,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/courselist.xlsx'

# %% [markdown]
# ##### Practice
#
# Read your dataset from the `dataset` folder into a new DataFrame.

# %%
#load a csv.
nhis_person = pd.read_csv('../dataset/MusselSpat_2012.csv')
nhis_person.head()
# Out:
#       Individual Site Date_Collected Date_Processed  Algal_#  Algae_wt_(g)  \
# 0   DD_10Jun12_1   DD      10-Jun-12      29-Jun-14        2           NaN
# 1   DD_10Jun12_2   DD      10-Jun-12      29-Jun-14        3           NaN
# 2   DD_23Jun12_1   DD      23-Jun-12       1-Jul-14        1           NaN
# 3  DD_23Jun12_10   DD      23-Jun-12       1-Jul-14        5           NaN
# 4   DD_23Jun12_2   DD      23-Jun-12       1-Jul-14        1           NaN
#
#    Eyespot  OMU_size  Magnification Scope Initials   Size  Julian_Day
# 0      1.0      28.0            4.0     H       NM  0.700         162
# 1      1.0      32.0            4.0     H       NM  0.800         162
# 2      1.0      33.0            4.0     H       NM  0.825         175
# 3      1.0      30.0            4.0     H       NM  0.750         175
# 4      1.0      30.0            4.0     H       NM  0.750         175

# %%
banner = pd.read_csv('../dataset/MusselSpat_2012.csv', nrows=1)

colnames = list(banner.columns)
print(colnames)
banner2 = pd.read_csv('../dataset/MusselSpat_2012.csv',
                    names=colnames, skiprows=range(10), nrows=10)
banner2
# Out:
# ['Individual', 'Site', 'Date_Collected', 'Date_Processed', 'Algal_#', 'Algae_wt_(g)', 'Eyespot', 'OMU_size', 'Magnification', 'Scope', 'Initials', 'Size', 'Julian_Day']
#      Individual Site Date_Collected Date_Processed  Algal_#  Algae_wt_(g)  \
# 0  DD_23Jun12_7   DD      23-Jun-12       1-Jul-14        5           NaN
# 1  DD_23Jun12_8   DD      23-Jun-12       1-Jul-14        5           NaN
# 2  DD_23Jun12_9   DD      23-Jun-12       1-Jul-14        5           NaN
# 3  DD_28Jun12_1   DD      28-Jun-12       8-Jul-14        1           NaN
# 4  DD_28Jun12_2   DD      28-Jun-12       8-Jul-14        1           NaN
# 5  DD_28Jun12_3   DD      28-Jun-12       8-Jul-14        1           NaN
# 6  DD_28Jun12_4   DD      28-Jun-12       8-Jul-14        2           NaN
# 7  DD_28Jun12_5   DD      28-Jun-12       8-Jul-14        3           NaN
# 8  DD_28Jun12_6   DD      28-Jun-12       8-Jul-14        3           NaN
# 9  DD_28Jun12_7   DD      28-Jun-12       8-Jul-14        5           NaN
#
#    Eyespot  OMU_size  Magnification Scope Initials   Size  Julian_Day
# 0        1        29              4     H       NM  0.725         175
# 1        1        31              4     H       NM  0.775         175
# 2        1        33              4     H       NM  0.825         175
# 3        1        31              3     H       NM  1.033         180
# 4        1        27              3     H       NM  0.900         180
# 5        1        24              3     H       NM  0.800         180
# 6        1        32              3     H       NM  1.067         180
# 7        1        30              3     H       NM  1.000         180
# 8        1        28              3     H       NM  0.933         180
# 9        1        20              3     H       NM  0.667         180

# %% [markdown]
# #### Joining
#
# [Merge, join, and concatenate](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)

# %% [markdown]
# ##### Concatenating (merging top to bottom):

# %%
banner3 = pd.read_csv('../dataset/MusselSpat_2012.csv',
                    names=colnames, skiprows=range(100), nrows=10)

#ignore index means we re-number the rows.
classes = pd.concat([banner2, banner3], ignore_index=True)
classes
# Out:
#        Individual Site Date_Collected Date_Processed  Algal_#  Algae_wt_(g)  \
# 0    DD_23Jun12_7   DD      23-Jun-12       1-Jul-14        5           NaN
# 1    DD_23Jun12_8   DD      23-Jun-12       1-Jul-14        5           NaN
# 2    DD_23Jun12_9   DD      23-Jun-12       1-Jul-14        5           NaN
# 3    DD_28Jun12_1   DD      28-Jun-12       8-Jul-14        1           NaN
# 4    DD_28Jun12_2   DD      28-Jun-12       8-Jul-14        1           NaN
# 5    DD_28Jun12_3   DD      28-Jun-12       8-Jul-14        1           NaN
# 6    DD_28Jun12_4   DD      28-Jun-12       8-Jul-14        2           NaN
# 7    DD_28Jun12_5   DD      28-Jun-12       8-Jul-14        3           NaN
# 8    DD_28Jun12_6   DD      28-Jun-12       8-Jul-14        3           NaN
# 9    DD_28Jun12_7   DD      28-Jun-12       8-Jul-14        5           NaN
# 10   LS_23Jun12_1   LS      23-Jun-12       9-May-14        1           NaN
# 11  LS_23Jun12_10   LS      23-Jun-12       9-May-14        1           NaN
# 12  LS_23Jun12_11   LS      23-Jun-12       9-May-14        2           NaN
# 13  LS_23Jun12_12   LS      23-Jun-12       9-May-14        2           NaN
# 14  LS_23Jun12_13   LS      23-Jun-12       9-May-14        2           NaN
# 15  LS_23Jun12_14   LS      23-Jun-12       9-May-14        2           NaN
# 16  LS_23Jun12_15   LS      23-Jun-12       9-May-14        2           NaN
# 17  LS_23Jun12_16   LS      23-Jun-12       9-May-14        2           NaN
# 18  LS_23Jun12_17   LS      23-Jun-12       9-May-14        2           NaN
# 19  LS_23Jun12_18   LS      23-Jun-12       9-May-14        2           NaN
#
#     Eyespot  OMU_size  Magnification Scope Initials   Size  Julian_Day
# 0         1        29              4     H       NM  0.725         175
# 1         1        31              4     H       NM  0.775         175
# 2         1        33              4     H       NM  0.825         175
# 3         1        31              3     H       NM  1.033         180
# 4         1        27              3     H       NM  0.900         180
# 5         1        24              3     H       NM  0.800         180
# 6         1        32              3     H       NM  1.067         180
# 7         1        30              3     H       NM  1.000         180
# 8         1        28              3     H       NM  0.933         180
# 9         1        20              3     H       NM  0.667         180
# 10        0        22              3     H       NM  0.733         175
# 11        0        27              3     H       NM  0.900         175
# 12        0        24              3     H       NM  0.800         175
# 13        0        25              3     H       NM  0.833         175
# 14        0        29              3     H       NM  0.967         175
# 15        0        26              3     H       NM  0.867         175
# 16        0        25              3     H       NM  0.833         175
# 17        1        20              3     H       NM  0.667         175
# 18        0        46              3     H       NM  1.533         175
# 19        0        30              3     H       NM  1.000         175

# %% [markdown]
# ##### Merging

# %%
nhis_family = pd.read_csv('../data/nhis/familyxx.csv')
nhis_family.head()
# Out:
#    FINT_Y_P  FINT_M_P  FMX  RECTYPE  SRVY_YR  HHX  FM_SIZE  FM_STRCP  FM_TYPE  \
# 0      2018         1    1       60     2018    1        1        11        1
# 1      2018         1    1       60     2018    4        3        41        4
# 2      2018         2    1       60     2018    6        4        41        4
# 3      2018         3    1       60     2018    8        3        41        4
# 4      2018         2    1       60     2018    9        1        11        1
#
#    FM_STRP  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0       11  ...      NaN        1         2         2       NaN     2
# 1       41  ...      4.0        2         1         1       1.0     2
# 2       41  ...      1.0        2         2         2       NaN     1
# 3       41  ...      3.0        3         2         1       NaN     2
# 4       11  ...      NaN        2         1         1       1.0     2
#
#    FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0         1         1      NaN       NaN
# 1         3         1      2.0       3.0
# 2         4         1      2.0       4.0
# 3         3         1      2.0       3.0
# 4         1         1      2.0       0.0
#
# [5 rows x 127 columns]

# %%
#Notes:  Use this variable [FMX] in combination with HHX and SRVY_YR 
#to identify individual families. 
nhis = pd.merge(nhis_person, nhis_family, on=['FMX', 'HHX', 'SRVY_YR'])
nhis.head()
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1    1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2    2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
#
#    ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0       1.0  ...      NaN        1         2         2       NaN     2
# 1       2.0  ...      4.0        2         1         1       1.0     2
# 2       0.0  ...      4.0        2         1         1       1.0     2
# 3       NaN  ...      4.0        2         1         1       1.0     2
# 4       1.0  ...      1.0        2         2         2       NaN     1
#
#    FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0         1         1      NaN       NaN
# 1         3         1      2.0       3.0
# 2         3         1      2.0       3.0
# 3         3         1      2.0       3.0
# 4         4         1      2.0       4.0
#
# [5 rows x 726 columns]

# %%
nhis = pd.merge(nhis_person, nhis_family, on=['FMX', 'HHX', 'SRVY_YR'])
nhis.head()

# %% [markdown]
# #### Summarizing

# %%
nhis.head()
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1    1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2    2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
#
#    ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0       1.0  ...      NaN        1         2         2       NaN     2
# 1       2.0  ...      4.0        2         1         1       1.0     2
# 2       0.0  ...      4.0        2         1         1       1.0     2
# 3       NaN  ...      4.0        2         1         1       1.0     2
# 4       1.0  ...      1.0        2         2         2       NaN     1
#
#    FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0         1         1      NaN       NaN
# 1         3         1      2.0       3.0
# 2         3         1      2.0       3.0
# 3         3         1      2.0       3.0
# 4         4         1      2.0       4.0
#
# [5 rows x 726 columns]

# %%
nhis.head(1)
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
#
#    ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 0       1.0  ...      NaN        1         2         2       NaN     2
#
#    FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 0         1         1      NaN       NaN
#
# [1 rows x 726 columns]

# %%
nhis.tail(3)
# Out:
#        FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 72828    1      NaN         4    2    2.0      2.0     NaN     NaN      NaN
# 72829    2      NaN         4    1    NaN      1.0     NaN     NaN      NaN
# 72830    1      NaN         4    2    NaN      NaN     NaN     NaN      NaN
#
#        ASTATFLG  ...  COVCONF  FHICOST  FMEDBILL  FMEDBPAY  FMEDBNOP  FSAF  \
# 72828       1.0  ...      2.0        2         2         2       NaN     2
# 72829       2.0  ...      2.0        2         2         2       NaN     2
# 72830       1.0  ...      NaN        1         2         2       NaN     2
#
#        FHICOVCT  FHICOVYN  FPRCOOH  FHIEBCCT
# 72828         2         1      2.0       2.0
# 72829         2         1      2.0       2.0
# 72830         1         1      2.0       0.0
#
# [3 rows x 726 columns]

# %%
nhis.describe()
# Out:
#                 FPX  AGE_CHG      INTV_QRT           SEX         NOWAF  \
# count  72831.000000      0.0  72831.000000  72831.000000  43253.000000
# mean       2.138334      NaN      2.352542      1.511897      1.994567
# std        1.338204      NaN      1.035801      0.499862      0.096853
# min        1.000000      NaN      1.000000      1.000000      1.000000
# 25%        1.000000      NaN      1.000000      1.000000      2.000000
# 50%        2.000000      NaN      2.000000      2.000000      2.000000
# 75%        3.000000      NaN      3.000000      2.000000      2.000000
# max       13.000000      NaN      4.000000      2.000000      9.000000
#
#             FSPOUS2       COHAB1       COHAB2      FCOHAB3      ASTATFLG  ...  \
# count  30354.000000  4082.000000  1541.000000  4082.000000  56166.000000  ...
# mean       1.576596     1.673689     2.911097     1.651886      1.382990  ...
# std        0.662259     0.776296     0.698245     0.868227      0.661738  ...
# min        1.000000     1.000000     1.000000     1.000000      0.000000  ...
# 25%        1.000000     1.000000     3.000000     1.000000      1.000000  ...
# 50%        2.000000     2.000000     3.000000     2.000000      1.000000  ...
# 75%        2.000000     2.000000     3.000000     2.000000      2.000000  ...
# max       10.000000     9.000000     9.000000    11.000000      4.000000  ...
#
#             COVCONF       FHICOST      FMEDBILL      FMEDBPAY      FMEDBNOP  \
# count  44055.000000  72831.000000  72831.000000  72831.000000  10357.000000
# mean       2.828101      2.158271      1.878829      1.802543      1.617071
# std        1.309343      1.773005      0.489456      0.670369      1.094391
# min        1.000000      0.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000      2.000000      2.000000      1.000000
# 50%        3.000000      2.000000      2.000000      2.000000      1.000000
# 75%        4.000000      3.000000      2.000000      2.000000      2.000000
# max        9.000000      9.000000      9.000000      9.000000      9.000000
#
#                FSAF      FHICOVCT      FHICOVYN       FPRCOOH      FHIEBCCT
# count  72831.000000  72831.000000  72831.000000  49263.000000  52241.000000
# mean       1.948758      2.916011      1.056858      1.926395      2.335120
# std        0.895844      1.694995      0.404043      0.391930      1.718593
# min        1.000000      0.000000      1.000000      1.000000      0.000000
# 25%        2.000000      2.000000      1.000000      2.000000      1.000000
# 50%        2.000000      3.000000      1.000000      2.000000      2.000000
# 75%        2.000000      4.000000      1.000000      2.000000      4.000000
# max        9.000000     12.000000      9.000000      9.000000     10.000000
#
# [8 rows x 723 columns]

# %%
nhis.sum().head()
# Out:
# FPX         155737.0
# AGE_CHG          0.0
# INTV_QRT    171338.0
# SEX         110113.0
# NOWAF        86271.0
# dtype: float64

# %%
bookreq.quantile(.5)
# Out:
# year                   2014.0
# total_book_requests     200.5
# rock_book_requests       48.0
# scili_book_requests       8.5
# orwig_book_requests      34.0
# hay_book_requests         0.0
# Name: 0.5, dtype: float64

# %%
bookreq.quantile([.25, .5, .75])
# Out:
#         year  total_book_requests  rock_book_requests  scili_book_requests  \
# 0.25  2010.0                27.25               19.75                 0.00
# 0.50  2014.0               200.50               48.00                 8.50
# 0.75  2017.0              1199.50              921.50                78.75
#
#       orwig_book_requests  hay_book_requests
# 0.25                  0.0                0.0
# 0.50                 34.0                0.0
# 0.75                182.0                0.0

# %%
bookreq.mean()
# Out:
# year                   2013.383333
# total_book_requests     619.416667
# rock_book_requests      483.666667
# scili_book_requests      39.150000
# orwig_book_requests      95.766667
# hay_book_requests         0.833333
# dtype: float64

# %% [markdown]
# #### Cleaning

# %% [markdown]
# We can search the entire dataframe for a value.

# %%
banner.astype(np.object)  == 'BIOL'
# Out:
#          CRN   Term  Description  Schedule  Schedule desc  Course title  \
# 0      False  False        False     False          False         False
# 1      False  False        False     False          False         False
# 2      False  False        False     False          False         False
# 3      False  False        False     False          False         False
# 4      False  False        False     False          False         False
# 5      False  False        False     False          False         False
# 6      False  False        False     False          False         False
# 7      False  False        False     False          False         False
# 8      False  False        False     False          False         False
# 9      False  False        False     False          False         False
# 10     False  False        False     False          False         False
# 11     False  False        False     False          False         False
# 12     False  False        False     False          False         False
# 13     False  False        False     False          False         False
# 14     False  False        False     False          False         False
# 15     False  False        False     False          False         False
# 16     False  False        False     False          False         False
# 17     False  False        False     False          False         False
# 18     False  False        False     False          False         False
# 19     False  False        False     False          False         False
# 20     False  False        False     False          False         False
# 21     False  False        False     False          False         False
# 22     False  False        False     False          False         False
# 23     False  False        False     False          False         False
# 24     False  False        False     False          False         False
# 25     False  False        False     False          False         False
# 26     False  False        False     False          False         False
# 27     False  False        False     False          False         False
# 28     False  False        False     False          False         False
# 29     False  False        False     False          False         False
# ...      ...    ...          ...       ...            ...           ...
# 13579  False  False        False     False          False         False
# 13580  False  False        False     False          False         False
# 13581  False  False        False     False          False         False
# 13582  False  False        False     False          False         False
# 13583  False  False        False     False          False         False
# 13584  False  False        False     False          False         False
# 13585  False  False        False     False          False         False
# 13586  False  False        False     False          False         False
# 13587  False  False        False     False          False         False
# 13588  False  False        False     False          False         False
# 13589  False  False        False     False          False         False
# 13590  False  False        False     False          False         False
# 13591  False  False        False     False          False         False
# 13592  False  False        False     False          False         False
# 13593  False  False        False     False          False         False
# 13594  False  False        False     False          False         False
# 13595  False  False        False     False          False         False
# 13596  False  False        False     False          False         False
# 13597  False  False        False     False          False         False
# 13598  False  False        False     False          False         False
# 13599  False  False        False     False          False         False
# 13600  False  False        False     False          False         False
# 13601  False  False        False     False          False         False
# 13602  False  False        False     False          False         False
# 13603  False  False        False     False          False         False
# 13604  False  False        False     False          False         False
# 13605  False  False        False     False          False         False
# 13606  False  False        False     False          False         False
# 13607  False  False        False     False          False         False
# 13608  False  False        False     False          False         False
#
#        Subject  Subject desc  Course number  Section  Text narrative  \
# 0        False         False          False    False           False
# 1        False         False          False    False           False
# 2         True         False          False    False           False
# 3         True         False          False    False           False
# 4         True         False          False    False           False
# 5         True         False          False    False           False
# 6         True         False          False    False           False
# 7         True         False          False    False           False
# 8         True         False          False    False           False
# 9         True         False          False    False           False
# 10        True         False          False    False           False
# 11        True         False          False    False           False
# 12        True         False          False    False           False
# 13        True         False          False    False           False
# 14        True         False          False    False           False
# 15        True         False          False    False           False
# 16        True         False          False    False           False
# 17        True         False          False    False           False
# 18        True         False          False    False           False
# 19        True         False          False    False           False
# 20        True         False          False    False           False
# 21        True         False          False    False           False
# 22        True         False          False    False           False
# 23        True         False          False    False           False
# 24        True         False          False    False           False
# 25        True         False          False    False           False
# 26        True         False          False    False           False
# 27        True         False          False    False           False
# 28        True         False          False    False           False
# 29        True         False          False    False           False
# ...        ...           ...            ...      ...             ...
# 13579    False         False          False    False           False
# 13580    False         False          False    False           False
# 13581    False         False          False    False           False
# 13582    False         False          False    False           False
# 13583    False         False          False    False           False
# 13584    False         False          False    False           False
# 13585    False         False          False    False           False
# 13586    False         False          False    False           False
# 13587    False         False          False    False           False
# 13588    False         False          False    False           False
# 13589    False         False          False    False           False
# 13590    False         False          False    False           False
# 13591    False         False          False    False           False
# 13592    False         False          False    False           False
# 13593    False         False          False    False           False
# 13594    False         False          False    False           False
# 13595    False         False          False    False           False
# 13596    False         False          False    False           False
# 13597    False         False          False    False           False
# 13598    False         False          False    False           False
# 13599    False         False          False    False           False
# 13600    False         False          False    False           False
# 13601    False         False          False    False           False
# 13602    False         False          False    False           False
# 13603    False         False          False    False           False
# 13604    False         False          False    False           False
# 13605    False         False          False    False           False
# 13606    False         False          False    False           False
# 13607    False         False          False    False           False
# 13608    False         False          False    False           False
#
#        Max enrollment  Primary instructor first name  \
# 0               False                          False
# 1               False                          False
# 2               False                          False
# 3               False                          False
# 4               False                          False
# 5               False                          False
# 6               False                          False
# 7               False                          False
# 8               False                          False
# 9               False                          False
# 10              False                          False
# 11              False                          False
# 12              False                          False
# 13              False                          False
# 14              False                          False
# 15              False                          False
# 16              False                          False
# 17              False                          False
# 18              False                          False
# 19              False                          False
# 20              False                          False
# 21              False                          False
# 22              False                          False
# 23              False                          False
# 24              False                          False
# 25              False                          False
# 26              False                          False
# 27              False                          False
# 28              False                          False
# 29              False                          False
# ...               ...                            ...
# 13579           False                          False
# 13580           False                          False
# 13581           False                          False
# 13582           False                          False
# 13583           False                          False
# 13584           False                          False
# 13585           False                          False
# 13586           False                          False
# 13587           False                          False
# 13588           False                          False
# 13589           False                          False
# 13590           False                          False
# 13591           False                          False
# 13592           False                          False
# 13593           False                          False
# 13594           False                          False
# 13595           False                          False
# 13596           False                          False
# 13597           False                          False
# 13598           False                          False
# 13599           False                          False
# 13600           False                          False
# 13601           False                          False
# 13602           False                          False
# 13603           False                          False
# 13604           False                          False
# 13605           False                          False
# 13606           False                          False
# 13607           False                          False
# 13608           False                          False
#
#        Primary instructor last name  Primary instructor email  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
# 5                             False                     False
# 6                             False                     False
# 7                             False                     False
# 8                             False                     False
# 9                             False                     False
# 10                            False                     False
# 11                            False                     False
# 12                            False                     False
# 13                            False                     False
# 14                            False                     False
# 15                            False                     False
# 16                            False                     False
# 17                            False                     False
# 18                            False                     False
# 19                            False                     False
# 20                            False                     False
# 21                            False                     False
# 22                            False                     False
# 23                            False                     False
# 24                            False                     False
# 25                            False                     False
# 26                            False                     False
# 27                            False                     False
# 28                            False                     False
# 29                            False                     False
# ...                             ...                       ...
# 13579                         False                     False
# 13580                         False                     False
# 13581                         False                     False
# 13582                         False                     False
# 13583                         False                     False
# 13584                         False                     False
# 13585                         False                     False
# 13586                         False                     False
# 13587                         False                     False
# 13588                         False                     False
# 13589                         False                     False
# 13590                         False                     False
# 13591                         False                     False
# 13592                         False                     False
# 13593                         False                     False
# 13594                         False                     False
# 13595                         False                     False
# 13596                         False                     False
# 13597                         False                     False
# 13598                         False                     False
# 13599                         False                     False
# 13600                         False                     False
# 13601                         False                     False
# 13602                         False                     False
# 13603                         False                     False
# 13604                         False                     False
# 13605                         False                     False
# 13606                         False                     False
# 13607                         False                     False
# 13608                         False                     False
#
#        Primary instructor Brown ID  Primary Instructor NetID  Course group
# 0                            False                     False         False
# 1                            False                     False         False
# 2                            False                     False         False
# 3                            False                     False         False
# 4                            False                     False         False
# 5                            False                     False         False
# 6                            False                     False         False
# 7                            False                     False         False
# 8                            False                     False         False
# 9                            False                     False         False
# 10                           False                     False         False
# 11                           False                     False         False
# 12                           False                     False         False
# 13                           False                     False         False
# 14                           False                     False         False
# 15                           False                     False         False
# 16                           False                     False         False
# 17                           False                     False         False
# 18                           False                     False         False
# 19                           False                     False         False
# 20                           False                     False         False
# 21                           False                     False         False
# 22                           False                     False         False
# 23                           False                     False         False
# 24                           False                     False         False
# 25                           False                     False         False
# 26                           False                     False         False
# 27                           False                     False         False
# 28                           False                     False         False
# 29                           False                     False         False
# ...                            ...                       ...           ...
# 13579                        False                     False         False
# 13580                        False                     False         False
# 13581                        False                     False         False
# 13582                        False                     False         False
# 13583                        False                     False         False
# 13584                        False                     False         False
# 13585                        False                     False         False
# 13586                        False                     False         False
# 13587                        False                     False         False
# 13588                        False                     False         False
# 13589                        False                     False         False
# 13590                        False                     False         False
# 13591                        False                     False         False
# 13592                        False                     False         False
# 13593                        False                     False         False
# 13594                        False                     False         False
# 13595                        False                     False         False
# 13596                        False                     False         False
# 13597                        False                     False         False
# 13598                        False                     False         False
# 13599                        False                     False         False
# 13600                        False                     False         False
# 13601                        False                     False         False
# 13602                        False                     False         False
# 13603                        False                     False         False
# 13604                        False                     False         False
# 13605                        False                     False         False
# 13606                        False                     False         False
# 13607                        False                     False         False
# 13608                        False                     False         False
#
# [13609 rows x 18 columns]

# %% [markdown]
#  The `any()` method will tell us which columns contain a value:

# %%
(banner.astype(np.object)  == 'BIOL').any()
# Out:
# CRN                              False
# Term                             False
# Description                      False
# Schedule                         False
# Schedule desc                    False
# Course title                     False
# Subject                           True
# Subject desc                     False
# Course number                    False
# Section                          False
# Text narrative                   False
# Max enrollment                   False
# Primary instructor first name    False
# Primary instructor last name     False
# Primary instructor email         False
# Primary instructor Brown ID      False
# Primary Instructor NetID         False
# Course group                     False
# dtype: bool

# %% [markdown]
# The above methods don't work with `NaN` (missing values) because `NaN` doesn't equal itself:

# %%
np.nan == np.nan
# Out:
# False

# %% [markdown]
# We have to use the `isnull()` method to find `NaN`.

# %%
#Are there missing values?
pd.isnull(banner).any()
# Out:
# CRN                              False
# Term                             False
# Description                      False
# Schedule                         False
# Schedule desc                    False
# Course title                     False
# Subject                          False
# Subject desc                     False
# Course number                    False
# Section                          False
# Text narrative                    True
# Max enrollment                   False
# Primary instructor first name     True
# Primary instructor last name      True
# Primary instructor email          True
# Primary instructor Brown ID       True
# Primary Instructor NetID          True
# Course group                     False
# dtype: bool

# %%
NA = np.nan
data = [[10, 11, NA, 8],[5,4,5,8],[9,9,3,4], [NA, NA, NA, NA], [NA, 4, 5, 9]]
dr = pd.DataFrame(data)
dr
# Out:
#       0     1    2    3
# 0  10.0  11.0  NaN  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3   NaN   NaN  NaN  NaN
# 4   NaN   4.0  5.0  9.0

# %% [markdown]
# Pandas provides a couple of built-in methods for dealing with missing values. `dropna()` will remove them, along with the entire row they belong in.

# %%
dr.dropna()
# Out:
#      0    1    2    3
# 1  5.0  4.0  5.0  8.0
# 2  9.0  9.0  3.0  4.0

# %%
#Drop the columns instead.
dr.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#Only remove rows where all values are `NaN`.
dr.dropna(how='all')
# Out:
#       0     1    2    3
# 0  10.0  11.0  NaN  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 4   NaN   4.0  5.0  9.0

# %% [markdown]
# You can also fill in missing values using the `fillna()` function:

# %%
#replace them all with zeroes.
dr.fillna(0)
# Out:
#       0     1    2    3
# 0  10.0  11.0  0.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3   0.0   0.0  0.0  0.0
# 4   0.0   4.0  5.0  9.0

# %%
#Use a dictionary to set different values per-column.
dr.fillna({0: 10, 2: 5})
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3  10.0   NaN  5.0  NaN
# 4  10.0   4.0  5.0  9.0

# %%
#Make changes in place:
dr.fillna({0: 10, 2: 5}, inplace=True)
dr
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3  10.0   NaN  5.0  NaN
# 4  10.0   4.0  5.0  9.0

# %%
#staging.
dr.iloc[2:,1] = NA
dr
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   NaN  3.0  4.0
# 3  10.0   NaN  5.0  NaN
# 4  10.0   NaN  5.0  9.0

# %%
#Fill forward
dr.fillna(method='ffill')
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   4.0  3.0  4.0
# 3  10.0   4.0  5.0  4.0
# 4  10.0   4.0  5.0  9.0

# %%
#Backwards
dr.fillna(method='bfill')
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   NaN  3.0  4.0
# 3  10.0   NaN  5.0  9.0
# 4  10.0   NaN  5.0  9.0

# %%
#Limit how many rows forward.
dr.fillna(method='ffill', limit=2)
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   4.0  3.0  4.0
# 3  10.0   4.0  5.0  4.0
# 4  10.0   NaN  5.0  9.0

# %% [markdown]
# You can also use functions to provide the values.

# %%
#Fill with the mean.
dr.fillna(dr.mean())
# Out:
#       0     1    2     3
# 0  10.0  11.0  5.0  8.00
# 1   5.0   4.0  5.0  8.00
# 2   9.0   7.5  3.0  4.00
# 3  10.0   7.5  5.0  7.25
# 4  10.0   7.5  5.0  9.00

# %%
dr.fillna(dr.median())
# Out:
#       0     1    2    3
# 0  10.0  11.0  5.0  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   7.5  3.0  4.0
# 3  10.0   7.5  5.0  8.0
# 4  10.0   7.5  5.0  9.0

# %%
np.mean(pd.DataFrame([dr[2].shift(1), dr[2].shift(-1)]))
# Out:
# 0    5.0
# 1    4.0
# 2    5.0
# 3    4.0
# 4    5.0
# dtype: float64

# %% [markdown]
# #### Find and remove duplicates

# %%
#staging
dr2 = pd.DataFrame(data + [[5,4,5,8]])
dr2
# Out:
#       0     1    2    3
# 0  10.0  11.0  NaN  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3   NaN   NaN  NaN  NaN
# 4   NaN   4.0  5.0  9.0
# 5   5.0   4.0  5.0  8.0

# %%
#The last row is a duplicate
dr2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
dr2.drop_duplicates()
# Out:
#       0     1    2    3
# 0  10.0  11.0  NaN  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3   NaN   NaN  NaN  NaN
# 4   NaN   4.0  5.0  9.0

# %%
#Keep the last one instead
dr2.drop_duplicates(keep='last')
# Out:
#       0     1    2    3
# 0  10.0  11.0  NaN  8.0
# 2   9.0   9.0  3.0  4.0
# 3   NaN   NaN  NaN  NaN
# 4   NaN   4.0  5.0  9.0
# 5   5.0   4.0  5.0  8.0

# %%
#Based only on some columns.
dr2.drop_duplicates([1,2])
# Out:
#       0     1    2    3
# 0  10.0  11.0  NaN  8.0
# 1   5.0   4.0  5.0  8.0
# 2   9.0   9.0  3.0  4.0
# 3   NaN   NaN  NaN  NaN

# %% [markdown]
# #### [Replace values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html)

# %%
df = pd.DataFrame({'A': ['bat', 'foo', 'bait'],
                    'B': ['abc', 'bar', 'xyz']})
df
# Out:
#       A    B
# 0   bat  abc
# 1   foo  bar
# 2  bait  xyz

# %%
df.replace(to_replace=r'^ba.$', value='new', regex=True)
# Out:
#       A    B
# 0   new  abc
# 1   foo  new
# 2  bait  xyz

# %% [markdown]
# #### Writing files

# %%
icd.to_csv('../dataset/icd.csv')

# %% [markdown]
# ##### Practice
#
# Write your currently-loaded dataset to a new file in your `../dataset` folder.

# %%
MS2.to_csv('../dataset/MusselSpat_cleaned.csv')
