# %% [markdown]
# # Assignment 8
#
# *(Due Saturday, November 16, 2019 at noon.)*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
# Out:
#    Unnamed: 0     Individual Site Date_Collected Date_Processed  Algal_#  \
# 0           0   DD_10Jun12_1   DD      10-Jun-12      29-Jun-14        2
# 1           1   DD_10Jun12_2   DD      10-Jun-12      29-Jun-14        3
# 2           2   DD_23Jun12_1   DD      23-Jun-12       1-Jul-14        1
# 3           3  DD_23Jun12_10   DD      23-Jun-12       1-Jul-14        5
# 4           4   DD_23Jun12_2   DD      23-Jun-12       1-Jul-14        1
#
#    Algae_wt_g  Eyespot  OMU_size  Magnification Scope Initials   Size  \
# 0         NaN      1.0      28.0            4.0     H       NM  0.700
# 1         NaN      1.0      32.0            4.0     H       NM  0.800
# 2         NaN      1.0      33.0            4.0     H       NM  0.825
# 3         NaN      1.0      30.0            4.0     H       NM  0.750
# 4         NaN      1.0      30.0            4.0     H       NM  0.750
#
#    Julian_Day
# 0         162
# 1         162
# 2         175
# 3         175
# 4         175

# %% [markdown]
# Load your dataset and create at least one visualization involving at least two variables (columns). Explain the relevance of this graph in the Markdown cell below, and use comments to document the code you use to produce it.

# %%
#Load the dataset as a csv and assign to variable spat_data
spat_data = pd.read_csv('../dataset/MusselSpat_cleaned.csv')
spat_data.head()
# Out:
#    Unnamed: 0     Individual Site Date_Collected Date_Processed  Algal_#  \
# 0           0   DD_10Jun12_1   DD      10-Jun-12      29-Jun-14        2
# 1           1   DD_10Jun12_2   DD      10-Jun-12      29-Jun-14        3
# 2           2   DD_23Jun12_1   DD      23-Jun-12       1-Jul-14        1
# 3           3  DD_23Jun12_10   DD      23-Jun-12       1-Jul-14        5
# 4           4   DD_23Jun12_2   DD      23-Jun-12       1-Jul-14        1
#
#    Algae_wt_g  Eyespot  OMU_size  Magnification Scope Initials   Size  \
# 0         NaN      1.0      28.0            4.0     H       NM  0.700
# 1         NaN      1.0      32.0            4.0     H       NM  0.800
# 2         NaN      1.0      33.0            4.0     H       NM  0.825
# 3         NaN      1.0      30.0            4.0     H       NM  0.750
# 4         NaN      1.0      30.0            4.0     H       NM  0.750
#
#    Julian_Day
# 0         162
# 1         162
# 2         175
# 3         175
# 4         175

# %%
#calculating the average size (mm) for each date across each site
for site in np.unique(spat_data.Site):
    site_data = spat_data.loc[spat_data['Site'] == site] #locating the 5 sampling sites in the dataset
    collection_dates = np.unique(site_data.Julian_Day) #returning unique dates for each site 
    site_sizes = []
    for date in collection_dates:
        date_data = site_data.loc[site_data['Julian_Day'] == date]
        avg_date_size = np.mean(date_data.Size) #calculating the mean size for each date across all sites
        site_sizes.append(avg_date_size)
    plt.plot(collection_dates, site_sizes, label = site) #plotting mean sizes (y) over time (x)
    plt.suptitle('Change in Mussel Spat Size over Time') #Setting a title
    plt.xlabel('Julian Day') # x-axis label
    plt.ylabel('Average Mussel Spat Size (mm)') # y-axis label
    plt.legend() # adding a legend
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The figure above shows the change in mussel spat sizes over the duration of the summer (mid April - early September) across all 5 sampling sites. Despite a few minor peaks early in the summer all 5 sites see an increase in mussel spat size as the summer progresses. This means that spat are growing and developing over the duration of the summer, which is likely correlated to the concentration of food in the water. Peaks at specific sites could be a result of outlier individuals or local environmental factors - a possible increase in food supply earlier in the summer due to an increase in nutrient supply from land runoff.
